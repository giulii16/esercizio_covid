# %% [markdown]
# # esercizio covid

# %%
import numpy as np
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt

# %%
datagen = pd.read_csv('DatiCovid', delimiter = ',',header=0)
datagen
# Out:
#                       data stato  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00   ITA              13               Abruzzo
# 1      2020-02-24T18:00:00   ITA              17            Basilicata
# 2      2020-02-24T18:00:00   ITA              18              Calabria
# 3      2020-02-24T18:00:00   ITA              15              Campania
# 4      2020-02-24T18:00:00   ITA               8        Emilia-Romagna
# ...                    ...   ...             ...                   ...
# 28282  2023-11-01T17:00:00   ITA              19               Sicilia
# 28283  2023-11-01T17:00:00   ITA               9               Toscana
# 28284  2023-11-01T17:00:00   ITA              10                Umbria
# 28285  2023-11-01T17:00:00   ITA               2         Valle d'Aosta
# 28286  2023-11-01T17:00:00   ITA               5                Veneto
#
#              lat       long  ricoverati_con_sintomi  terapia_intensiva  \
# ...

# %%
data = datagen[datagen["denominazione_regione"]=="Abruzzo"]
data
# Out:
#                       data stato  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00   ITA              13               Abruzzo
# 21     2020-02-25T18:00:00   ITA              13               Abruzzo
# 42     2020-02-26T18:00:00   ITA              13               Abruzzo
# 63     2020-02-27T18:00:00   ITA              13               Abruzzo
# 84     2020-02-28T18:00:00   ITA              13               Abruzzo
# ...                    ...   ...             ...                   ...
# 28182  2023-10-28T17:00:00   ITA              13               Abruzzo
# 28203  2023-10-29T17:00:00   ITA              13               Abruzzo
# 28224  2023-10-30T17:00:00   ITA              13               Abruzzo
# 28245  2023-10-31T17:00:00   ITA              13               Abruzzo
# 28266  2023-11-01T17:00:00   ITA              13               Abruzzo
#
#              lat       long  ricoverati_con_sintomi  terapia_intensiva  \
# ...

# %%
datadef = data[['data','totale_positivi']]
datadef
# Out:
#                       data  totale_positivi
# 0      2020-02-24T18:00:00                0
# 21     2020-02-25T18:00:00                0
# 42     2020-02-26T18:00:00                0
# 63     2020-02-27T18:00:00                1
# 84     2020-02-28T18:00:00                1
# ...                    ...              ...
# 28182  2023-10-28T17:00:00             2866
# 28203  2023-10-29T17:00:00             2901
# 28224  2023-10-30T17:00:00             2864
# 28245  2023-10-31T17:00:00             2889
# 28266  2023-11-01T17:00:00             2943
#
# [1347 rows x 2 columns]

# %%
datadef.plot('data', 'totale_positivi')
# Out:
# <Axes: xlabel='data'>
